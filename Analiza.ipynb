# %%
import pandas as pd

pd.options.display.max_rows = 20

# %%
tekmovalci = pd.read_csv('athlete_events.csv', index_col = 'ID')

# %%
drzave = pd.read_csv('noc_regions.csv', encoding = 'utf-8')

# %%
tekmovalci.head(20)
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 6            Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# ...

# %%
tekmovalci[(tekmovalci.Age > 25.0) & (tekmovalci.Year >= 2016)]
# Out:
#                                           Name Sex   Age  Height  Weight  \
# ID
# 55                         Antonio Abadia Beci   M  26.0   170.0    65.0
# 73                                   Luc Abalo   M  31.0   182.0    86.0
# 141                               Clare Abbott   F  30.0   167.0    58.0
# 141                               Clare Abbott   F  30.0   167.0    58.0
# 149                      Mara Katherine Abbott   F  30.0   163.0    52.0
# 161                             Hossam Abdalla   M  28.0   203.0    97.0
# 203                          Ahmed Abdel Naeim   M  31.0   197.0    87.0
# 213                           Samy Abdel Razek   M  36.0   170.0    60.0
# 213                           Samy Abdel Razek   M  36.0   170.0    60.0
# 225                 Shaimaa Abdel-Latif-Hashad   F  35.0   165.0    57.0
# 227                             Ahmed Abdelaal   M  27.0   188.0    89.0
# 229                       Mohamed Ali Abdelaal   M  26.0   175.0    81.0
# ...

# %%
tekmovalci['Name'].unique()
# Out:
# array(['A Dijiang', 'A Lamusi', 'Gunnar Nielsen Aaby', ..., 'Andrzej ya',
#        'Piotr ya', 'Tomasz Ireneusz ya'], dtype=object)

# %%
len(tekmovalci['Name'].unique())
# Out:
# 134732

# %%
tekmovalci[tekmovalci['Medal'] == 'Gold'].sort_values('Sport')
# Out:
#                                      Name Sex   Age  Height  Weight  \
# ID
# 107506                  Hermann Schreiber   M  26.0     NaN     NaN
# 126365             Jean-Pierre Andr Vidal   M  24.0   175.0    80.0
# 116997                 Aksel Lund Svindal   M  27.0   189.0   100.0
# 56241                           Max Julen   M  22.0   170.0    64.0
# 69796         Theodore Sharp "Ted" Ligety   M  29.0   180.0    86.0
# 36846   Gretchen Claudia Fraser (Kunigk-)   F  28.0   163.0    53.0
# 69796         Theodore Sharp "Ted" Ligety   M  21.0   180.0    86.0
# 114511                        Roger Staub   M  23.0     NaN     NaN
# 95831                         Josef Polig   M  23.0   168.0    70.0
# 109730           Mikaela Pauline Shiffrin   F  18.0   170.0    64.0
# ...                                   ...  ..   ...     ...     ...
# 63601                         Istvn Kozma   M  24.0   198.0   125.0
# 63205                     Johannes Kotkas   M  37.0   184.0   115.0
# ...

# %%
tekmovalci[tekmovalci.Name == 'Kjetil Andr Aamodt']
# Out:
#                   Name Sex   Age  Height  Weight    Team  NOC        Games  \
# ID
# 20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR  1992 Winter
# 20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR  1992 Winter
# 20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR  1992 Winter
# 20  Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway  NOR  1992 Winter
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway  NOR  1994 Winter
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway  NOR  1994 Winter
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway  NOR  1994 Winter
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway  NOR  1994 Winter
# 20  Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway  NOR  1994 Winter
# 20  Kjetil Andr Aamodt   M  26.0   176.0    85.0  Norway  NOR  1998 Winter
# 20  Kjetil Andr Aamodt   M  26.0   176.0    85.0  Norway  NOR  1998 Winter
# ...

# %%
tekmovalci[tekmovalci.Name == 'Yuliya Andreyevna Yefimova']
# Out:
#                               Name Sex   Age  Height  Weight    Team  NOC  \
# ID
# 132765  Yuliya Andreyevna Yefimova   F  16.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  16.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  16.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  20.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  20.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  20.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  24.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  24.0   178.0    64.0  Russia  RUS
# 132765  Yuliya Andreyevna Yefimova   F  24.0   178.0    64.0  Russia  RUS
#
#               Games  Year  Season            City     Sport  \
# ID
# 132765  2008 Summer  2008  Summer         Beijing  Swimming
# 132765  2008 Summer  2008  Summer         Beijing  Swimming
# ...

# %%
tekmovalci[tekmovalci.Name == 'Mark Andrew Spitz']
# Out:
#                      Name Sex   Age  Height  Weight           Team  NOC  \
# ID
# 113912  Mark Andrew Spitz   M  18.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  18.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  18.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  18.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  18.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
# 113912  Mark Andrew Spitz   M  22.0   183.0    73.0  United States  USA
#
# ...

# %%
tekmovalci[tekmovalci.Name == 'Mikaela Pauline Shiffrin']
# Out:
#                             Name Sex   Age  Height  Weight           Team  \
# ID
# 109730  Mikaela Pauline Shiffrin   F  18.0   170.0    64.0  United States
# 109730  Mikaela Pauline Shiffrin   F  18.0   170.0    64.0  United States
#
#         NOC        Games  Year  Season   City          Sport  \
# ID
# 109730  USA  2014 Winter  2014  Winter  Sochi  Alpine Skiing
# 109730  USA  2014 Winter  2014  Winter  Sochi  Alpine Skiing
#
#                                      Event Medal
# ID
# 109730  Alpine Skiing Women's Giant Slalom   NaN
# 109730        Alpine Skiing Women's Slalom  Gold

# %%
st_medalj = tekmovalci.groupby('ID')['Year','Team','Medal'].nunique()
st = st_medalj.sort_values('Medal',ascending=False).head(30)
st[st['Medal'] == 3].head(30)
# Out:
#         Year  Team  Medal
# ID
# 51737      4     1      3
# 83448      2     1      3
# 119411     6     1      3
# 112515     1     1      3
# 126580     4     1      3
# 117541     4     1      3
# 22312      4     1      3
# 72466      4     1      3
# 88124      6     1      3
# 129051     2     1      3
# ...      ...   ...    ...
# 79514      4     1      3
# 20106      2     1      3
# 131538     3     1      3
# 43401      3     1      3
# 28501      2     1      3
# 36489      1     1      3
# 22243      4     1      3
# 45336      4     1      3
# 105305     2     1      3
# 28473      5     2      3
#
# [30 rows x 3 columns]

# %%
tekmovalci.groupby(by='Medal', as_index=False).agg({'Name': pd.Series.nunique})
# Out:
#     Medal   Name
# 0  Bronze  11867
# 1    Gold  10413
# 2  Silver  11430

# %%
tekmovalci_po_letih=tekmovalci.groupby('Name')['Games','Medal','Sport'].nunique()
tekmovalci_po_letih[tekmovalci_po_letih.Sport>1]
tekmovalci_po_letih_z_imeni = tekmovalci_po_letih.sort_values(['Name','Medal'],ascending = [False,False])
tekmovalci_po_letih_z_imeni
# Out:
#                                            Games  Medal  Sport
# Name
# zzet nce                                       2      0      1
# zzet Safer                                     1      0      1
# zman Graud                                     1      0      1
# zlem Kaya                                      2      0      1
# zge Krdar emberci                              1      0      1
# zge Bayrak                                     1      0      1
# zer Atei                                       1      0      1
# zden Ezinler                                   1      0      1
# zdemir Akbal                                   1      0      1
# zcan Ediz                                      1      0      1
# ...                                          ...    ...    ...
# A. Aanantha Sambu Mayavo                       1      0      1
# A Lamusi                                       1      0      1
# A Dijiang                                      1      0      1
# ...

# %%
tekmovalci_po_letih_nastopanja = tekmovalci.groupby('Name')['Name','Age','Medal']
#tekmovalci_po_letih_nastopanja.sort_values('Age', ascending = True)
#tekmovalci_po_letih_nastopanja.sort_values('Medal', ascending = False)

# %%
tekmo_po_letih_pada_zlata = tekmovalci_po_letih_z_imeni[tekmovalci_po_letih_z_imeni.Medal == 3]
tekmovalci_po_letih.groupby('Name').count()
# Out:
#                                            Games  Medal  Sport
# Name
#   Gabrielle Marie "Gabby" Adcock (White-)      1      1      1
#  Eleonora Margarida Josephina Scmitt           1      1      1
#  Jean Hauptmanns                               1      1      1
#  Luis ngel Fernando de los Santos Grossi       1      1      1
#  Th Anh                                        1      1      1
#  Th Ngn Thng                                   1      1      1
#  Tin Tun                                       1      1      1
# A Dijiang                                      1      1      1
# A Lamusi                                       1      1      1
# A. Aanantha Sambu Mayavo                       1      1      1
# ...                                          ...    ...    ...
# zcan Ediz                                      1      1      1
# zdemir Akbal                                   1      1      1
# zden Ezinler                                   1      1      1
# ...
