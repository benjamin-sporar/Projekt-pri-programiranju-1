# %%
import pandas as pd

pd.options.display.max_rows = 20

# %%
tekmovalci = pd.read_csv('athlete_events.csv', index_col = 'ID')

# %%
drzave = pd.read_csv('noc_regions.csv', encoding = 'utf-8')

# %%
tekmovalci.head(20)
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 6            Per Knut Aaland   M  31.0   188.0    75.0   United States  USA
# ...

# %%
tekmovalci[(tekmovalci.Age > 25.0) & (tekmovalci.Year >= 2016)]
# Out:
#                                           Name Sex   Age  Height  Weight  \
# ID
# 55                         Antonio Abadia Beci   M  26.0   170.0    65.0
# 73                                   Luc Abalo   M  31.0   182.0    86.0
# 141                               Clare Abbott   F  30.0   167.0    58.0
# 141                               Clare Abbott   F  30.0   167.0    58.0
# 149                      Mara Katherine Abbott   F  30.0   163.0    52.0
# 161                             Hossam Abdalla   M  28.0   203.0    97.0
# 203                          Ahmed Abdel Naeim   M  31.0   197.0    87.0
# 213                           Samy Abdel Razek   M  36.0   170.0    60.0
# 213                           Samy Abdel Razek   M  36.0   170.0    60.0
# 225                 Shaimaa Abdel-Latif-Hashad   F  35.0   165.0    57.0
# 227                             Ahmed Abdelaal   M  27.0   188.0    89.0
# 229                       Mohamed Ali Abdelaal   M  26.0   175.0    81.0
# ...

# %%
tekmovalci['Name'].unique().tolist()
# Out:
# ['A Dijiang',
#  'A Lamusi',
#  'Gunnar Nielsen Aaby',
#  'Edgar Lindenau Aabye',
#  'Christine Jacoba Aaftink',
#  'Per Knut Aaland',
#  'John Aalberg',
#  'Cornelia "Cor" Aalten (-Strannood)',
#  'Antti Sami Aalto',
#  'Einar Ferdinand "Einari" Aalto',
#  'Jorma Ilmari Aalto',
#  'Jyri Tapani Aalto',
#  'Minna Maarit Aalto',
#  'Pirjo Hannele Aalto (Mattila-)',
#  'Arvo Ossian Aaltonen',
#  'Juhamatti Tapio Aaltonen',
#  'Paavo Johannes Aaltonen',
#  'Timo Antero Aaltonen',
#  'Win Valdemar Aaltonen',
#  'Kjetil Andr Aamodt',
#  'Ragnhild Margrethe Aamodt',
#  'Andreea Aanei',
#  'Fritz Aanes',
#  'Nils Egil Aaness',
#  'Alf Lied Aanning',
#  'Agnes Erika Aanonsen (-Eyde)',
#  'Johan Aantjes',
#  'Jan-Erik Aarberg',
#  'Willemien Aardenburg',
#  'Pepijn Aardewijn',
#  'Evald rma (rman-)',
#  'Olav Augunson Aarnes',
#  'Mika Lauri Aarnikka',
#  'Jamale (Djamel-) Aarrass (Ahrass-)',
#  'Dagfinn Sverre Aarskog',
#  'Stefan Remco Aartsen',
#  'Ann Kristin Aarnes',
#  'Karl Jan Aas',
# ...

# %%
len(tekmovalci['Name'].unique())
# Out:
# 134732

# %%
tekmovalci[tekmovalci['Medal'] == 'Gold']
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 73          20                         Kjetil Andr Aamodt   M  30.0   176.0
# 76          20                         Kjetil Andr Aamodt   M  30.0   176.0
# 78          20                         Kjetil Andr Aamodt   M  34.0   176.0
# 79          21                  Ragnhild Margrethe Aamodt   F  27.0   163.0
# 113         40                            Roald Edgar Aas   M  31.0     NaN
# 117         42                        Thomas Valentin Aas   M  25.0     NaN
# ...

# %%
tekmovalci.sort_values(by = 'Medal',ascending = False)[:100]
# Out:
#                                             Name Sex   Age  Height  Weight  \
# ID
# 68990                            Marek Leniewski   M  25.0   185.0    76.0
# 68384                             Walter Lehmann   M  29.0     NaN     NaN
# 68449                                     Lei Li   F  28.0   166.0    56.0
# 68440          Mirja Annikki Lehtonen (-Kierros)   F  21.0   165.0    54.0
# 68433                      Erkki Tapani Lehtonen   M  31.0   178.0    80.0
# 68416                 Lauri Aleksanteri Lehtinen   M  27.0   174.0    64.0
# 68415                      Jere Kalervo Lehtinen   M  32.0   183.0    88.5
# 68384                             Walter Lehmann   M  29.0     NaN     NaN
# 68384                             Walter Lehmann   M  29.0     NaN     NaN
# 68382                             Ulrich Lehmann   M  32.0   184.0    75.0
# 68288                           Patrick Lefoulon   M  26.0   175.0    73.0
# ...

# %%
tekmovalci.groupby('Name')['Medal'].nunique()
# Out:
# Name
#   Gabrielle Marie "Gabby" Adcock (White-)    0
#  Eleonora Margarida Josephina Scmitt         0
#  Jean Hauptmanns                             0
#  Luis ngel Fernando de los Santos Grossi     0
#  Th Anh                                      0
#  Th Ngn Thng                                 0
#  Tin Tun                                     0
# A Dijiang                                    0
# A Lamusi                                     0
# A. Aanantha Sambu Mayavo                     0
# A. Abdul Razzak                              0
# A. Albert                                    1
# A. Brun                                      0
# A. Buydens                                   0
# A. Charles Six                               0
# A. Christory                                 0
# A. Darnis                                    0
# A. Dubois                                    2
# A. Duponcheel                                0
# A. E. Page                                   0
# ...

# %%
tekmovalci.groupby(by='Medal', as_index=False).agg({'Name': pd.Series.nunique})
# Out:
#     Medal   Name
# 0  Bronze  11867
# 1    Gold  10413
# 2  Silver  11430

# %%
tekmovalci
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
tekmovalci_po_letih = tekmovalci.sort_values('Age', ascending = True)

# %%
tekmovalci_po_letih[tekmovalci_po_letih['Medal'] == 'Gold']
# Out:
#                                       Name Sex   Age  Height  Weight  \
# ID
# 100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 134381                         Klaus Zerta   M  13.0   165.0    48.0
# 60384                           Kim Yun-Mi   F  13.0   160.0    48.0
# 14142                        Hans Bourquin   M  13.0     NaN     NaN
# 26731   Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 37398                           Fu Mingxia   F  13.0   160.0    48.0
# 39866         Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 19456                       Giorgio Cesana   M  14.0     NaN     NaN
# 19456                       Giorgio Cesana   M  14.0     NaN     NaN
# 19456                       Giorgio Cesana   M  14.0     NaN     NaN
# ...                                    ...  ..   ...     ...     ...
# 124789                     Edmond Van Moer   M   NaN     NaN     NaN
# ...
